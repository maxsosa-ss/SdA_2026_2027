# %% [markdown]
# # Ejecución local de los distintos pipelines

# %% [markdown]
# ## Ambulatorio

# %% [markdown]
# Seguimiento diario de autorizaciones ambulatorias.

# %%
from src.pipelines.ambulatorio import run
run()

# %% [markdown]
# ## Farmacia y Vacunas

# %% [markdown]
# Seguimiento diario de farmacia y vacunas.

# %%
from src.pipelines.farmvac import run
run()

# %% [markdown]
# ## Provisión

# %% [markdown]
# Seguimiento diario de provisión.

# %%
from src.pipelines.provision import run

run()

# %% [markdown]
# ## Discapacidad

# %% [markdown]
# Seguimiento diario de discapacidad.

# %%
from src.pipelines.discapacidad import run

run()

# %% [markdown]
# ## Protesis

# %% [markdown]
# Seguimiento diario de prótesis.

# %%
from src.pipelines.protesis import run 

run()

# %% [markdown]
# ## Internaciones

# %% [markdown]
# Seguimiento diario de internaciones.

# %%
from src.pipelines.internaciones import run 

run()
# Out:
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: 'Cantidades v2' with ID: 'E44FF0D61F4904263C5EE4A9B6977657'
# Report object named: 'NE' with ID: '14772FE4A2472411C34CF3B8934268BA'
# ⚙️ Registros en Sanatoriales: 30
# ✅ internaciones_sanatorial: 30 registros en internaciones_sanatorial.parquet
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: 'Cantidades & Aut. Valorizadas v2' with ID: '958061A8F74E38D4A019EDAF1F12426A'
# Report object named: 'NE & Presupuesto v2' with ID: 'EA2159D88A49B2D8E2D8F7A78A1FF672'
# ⚙️ Registros en Quirúrgicas: 38
# ✅ internaciones_quirurgicas: 38 registros en internaciones_quirurgicas.parquet
# 💾 internaciones_sanatorial: 30 filas guardadas (2026-07-28) → sda.sqlite
# 💾 internaciones_quirurgicas: 38 filas guardadas (2026-07-28) → sda.sqlite
# [leer_tabla_df] rango 'consolidado_sanatorial': 568 filas leídas
# 💾 internaciones_consolidado_sanatorial: 30 filas guardadas (2026-07-28) → sda.sqlite
# [leer_tabla_df] rango 'consolidado_quirurgicas': 682 filas leídas
# 💾 internaciones_consolidado_quirurgicas: 38 filas guardadas (2026-07-28) → sda.sqlite
