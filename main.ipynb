# %%
from src.extract.ambulatorio import extract_complete
from src.load.ambulatorio import load_complete

df = extract_complete()
# Out:
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: '01.1 - AMBULATORIO' with ID: '6FFDEA91D9424E4D3C903E800B8C8D52'

# %%
df['Cantidad Prestaciones Aceptadas'] = 1

# %%
load_complete(df)
# Out:
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ✅ ambulatorio (complete): 358006 registros en raw.sqlite

# %%
from src.extract.ambulatorio import extract_u6m
from src.load.ambulatorio import load_u6m

df = extract_u6m()
load_u6m(df)
# Out:
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: '01.2 - AMBULATORIO - U6M' with ID: '1C7CE23E3342D3623628C6837F197F57'
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# 🗑️  Eliminados desde 2025-12-19: 254255 registros
# ✅ ambulatorio (u6m): 358006 registros en raw.sqlite

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('data/raw/raw.sqlite')
df_ambulatorio = pd.read_sql_query("SELECT * FROM ambulatorio", conn)
conn.close()

df_ambulatorio
# Out:
#        Subzona Direccion Comercial Asociado Fecha Proceso Autorización  \
# 0                                       F/D                 2025-10-01
# 1                                     CHACO                 2025-10-01
# 2                                     CHACO                 2025-10-01
# 3                                     CHACO                 2025-10-01
# 4                                     CHACO                 2025-10-01
# ...                                     ...                        ...
# 358001                             LA PLATA                 2026-06-18
# 358002                             LA PLATA                 2026-06-18
# 358003                             LA PLATA                 2026-06-18
# 358004                             LA PLATA                 2026-06-18
# 358005                             LA PLATA                 2026-06-18
#
#        Rubro Prestacion Gerencia Estrategica Periodo  \
# 0                                   Consulta  202510
# 1                                    Pension  202510
# 2                                     Optica  202510
# 3                                  Anestesia  202510
# 4                          Fisiokinesiologia  202510
# ...                                      ...     ...
# 358001                              Consulta  202606
# 358002                              Consulta  202606
# 358003                              Consulta  202606
# 358004                              Consulta  202606
# 358005                              Consulta  202606
#
#        Zona Direccion Comercial Asociado  \
# 0                                    F/D
# 1                                    NEA
# 2                                    NEA
# 3                                    NEA
# 4                                    NEA
# ...                                  ...
# 358001                   PROVINCIA BS AS
# 358002                   PROVINCIA BS AS
# 358003                   PROVINCIA BS AS
# 358004                   PROVINCIA BS AS
# 358005                   PROVINCIA BS AS
#
#        Subrubro Prestacion Gerencia Estrategica  \
# 0                         Videoconsulta Guardia
# 1                                Sin Clasificar
# 2                                Sin Clasificar
# 3                                Anestesiologia
# 4                                Sin Clasificar
# ...                                         ...
# 358001                                  Guardia
# 358002                               Programada
# 358003                     Videoconsulta Receta
# 358004                    Videoconsulta Guardia
# 358005                 Videoconsulta Programada
#
#         Cantidad Prestaciones Aceptadas
# 0                                     1
# 1                                     1
# 2                                     1
# 3                                     1
# 4                                     1
# ...                                 ...
# 358001                                3
# 358002                              192
# 358003                               11
# 358004                                7
# 358005                                6
#
# [358006 rows x 7 columns]

# %%
df_ambulatorio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451564 entries, 0 to 451563
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Rubro Prestacion Gerencia Estrategica     451564 non-null  object
#  1   Subzona Direccion Comercial Asociado      451564 non-null  object
#  2   Subrubro Prestacion Gerencia Estrategica  451564 non-null  object
#  3   Zona Direccion Comercial Asociado         451564 non-null  object
#  4   Periodo                                   451564 non-null  object
#  5   Fecha Proceso Autorización                451564 non-null  object
#  6   Cantidad Prestaciones Aceptadas           451564 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 24.1+ MB
