# %% [markdown]
# # Ejecución local de los distintos pipelines

# %% [markdown]
# ## Ambulatorio

# %% [markdown]
# Seguimiento diario de autorizaciones ambulatorias.

# %%
from src.pipelines.ambulatorio import run
run()
# Out:
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: '01.2 - AMBULATORIO - U6M' with ID: '1C7CE23E3342D3623628C6837F197F57'
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# 🗑️  Eliminados desde 2026-01-01: 252946 registros
# ✅ ambulatorio (u6m): 371378 registros en ambulatorio.parquet
# [leer_tabla_df] rango 'NE_amb!A1:F47629': 47628 filas leídas
# [leer_tabla_df] rango 'feriados!A1:C200': 165 filas leídas
# [leer_tabla_df] rango 'P_AMB!A1:Y2269': 2268 filas leídas
# [leer_tabla_df] rango 'D_AMB!A1:D1891': 1890 filas leídas
# [leer_tabla_df] rango 'conversor_amb!A1:E10207': 10206 filas leídas
# [leer_tabla_df] rango 'amb_rubro!A1:C19': 18 filas leídas
# [leer_tabla_df] rango 'amb_subrubro!A1:D90': 89 filas leídas
# 💾 amb_seg_diario: 1620 filas guardadas (2026-07-01) → sda.sqlite
# 💾 amb_general: 47628 filas guardadas (2026-07-01) → sda.sqlite

# %% [markdown]
# ## Farmacia y Vacunas

# %% [markdown]
# Seguimiento diario de farmacia y vacunas.

# %%
from src.pipelines.farmvac import run
run()
# Out:
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: '02.2 - FARMACIA - U6M' with ID: 'C50E5F1FDA44AD22759E94908AE08311'
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: '03.2 - VACUNAS - U6M' with ID: '0DF2498E204C203483BA2BA9A8C2005D'
# 🗑️  Eliminados desde 2026-01-01: 9730 registros
# ✅ farmvac (u6m): 13562 registros en farmvac.parquet
# [leer_tabla_df] rango 'NE_farm_Q!A1:F1765': 1764 filas leídas
# [leer_tabla_df] rango 'NE_farm_imp!A1:F1765': 1764 filas leídas
# [leer_tabla_df] rango 'feriados!A1:C200': 165 filas leídas
# 💾 farm_seg_diario: 30 filas guardadas (2026-07-01) → sda.sqlite
# 💾 farm_gral_q: 1764 filas guardadas (2026-07-01) → sda.sqlite
# 💾 farm_gral_imp: 1764 filas guardadas (2026-07-01) → sda.sqlite
# [leer_tabla_df] rango 'farm_proy_imp_diario': 4 filas leídas
# 💾 farm_seg_proy_imp: 1 filas guardadas (2026-07-01) → sda.sqlite

# %% [markdown]
# ## Provisión

# %% [markdown]
# Seguimiento diario de provisión.

# %%
from src.pipelines.provision import run

run()
# Out:
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: '04.1 - PROVISION' with ID: 'C41EA844C04CDA01937C65A9DB6E3E86'
# ⚙️ Registros en Autorizaciones PROVISION: 525
# ✅ provision: 525 registros en provision.parquet
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: '04.2 - PROVISION DIARIO' with ID: 'B9025BF74B447CED830040BECF1F02DE'
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ⚙️ Registros en PROVISION diario: 213
# ✅ provision_diario: 213 registros en provision_diario.parquet
# [leer_tabla_df] rango 'NE_provision!A1:D127': 126 filas leídas
# FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# [leer_tabla_df] rango 'feriados!A1:C200': 165 filas leídas
# 📅 Total días hábiles: 21.0 | Día hábil actual: 21.0 | Restantes: 0.0
# 💾 prov_gral: 126 filas guardadas (2026-07-01) → sda.sqlite
# 💾 prov_diario: 59 filas guardadas (2026-07-01) → sda.sqlite

# %% [markdown]
# ## Discapacidad

# %% [markdown]
# Seguimiento diario de discapacidad.

# %%
from src.pipelines.discapacidad import run

run()
# Out:
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: '05 - DISCAPACIDAD' with ID: 'B60FDA19E4423A89A9B718BCC1952ECA'
# ⚙️ Registros en Autorizaciones DISCAPACIDAD: 7501
# ✅ discapacidad: 7501 registros en discapacidad.parquet
# [leer_tabla_df] rango 'discapacidad!A1:F75': 74 filas leídas
# 💾 discapacidad: 1326 filas guardadas (2026-07-01) → sda.sqlite

# %% [markdown]
# ## Protesis

# %% [markdown]
# Seguimiento diario de prótesis.

# %%
from src.pipelines.protesis import run 

run()
# Out:
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: '06 - PROTESIS' with ID: 'C5DBD8592F4D6A3CED40B7848F9DFC0F'
# ⚙️ Registros en Autorizaciones PROTESIS: 726
# ✅ protesis: 726 registros en protesis.parquet
# 💾 protesis: 726 filas guardadas (2026-07-01) → sda.sqlite

# %% [markdown]
# ## Internaciones

# %% [markdown]
# Seguimiento diario de internaciones.

# %%
from src.pipelines.internaciones import run 

run()
# Out:
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: 'Cantidades' with ID: 'C71DAF365641E079133675B4BA255443'
# Report object named: 'NE' with ID: '14772FE4A2472411C34CF3B8934268BA'
# ⚙️ Registros en Sanatoriales: 32
# ✅ internaciones_sanatorial: 32 registros en internaciones_sanatorial.parquet
# Connection to Strategy One Intelligence Server has been established.
# Project selected in Connection object:
# Project object named: 'Salud' with ID: 'DAE6DF9811D67BD9500010A51D1D2ADA'
# Report object named: 'Cantidades & Aut. Valorizadas v2' with ID: 'E5D59D0A824A139CA57DB8A56084BF24'
# Report object named: 'NE & Presupuesto v2' with ID: 'EA2159D88A49B2D8E2D8F7A78A1FF672'
# ⚙️ Registros en Quirúrgicas: 37
# ✅ internaciones_quirurgicas: 37 registros en internaciones_quirurgicas.parquet
# 💾 internaciones_sanatorial: 32 filas guardadas (2026-07-01) → sda.sqlite
# 💾 internaciones_quirurgicas: 37 filas guardadas (2026-07-01) → sda.sqlite
# [leer_tabla_df] rango 'consolidado_sanatorial': 64 filas leídas
# 💾 internaciones_consolidado_sanatorial: 32 filas guardadas (2026-07-01) → sda.sqlite
# [leer_tabla_df] rango 'consolidado_quirurgicas': 74 filas leídas
# 💾 internaciones_consolidado_quirurgicas: 37 filas guardadas (2026-07-01) → sda.sqlite
