# %%
from src.stage.ambulatorio import read as stage_read

df_ambulatorio = stage_read()
df_ambulatorio
# Out:
#        Subrubro Prestacion Gerencia Estrategica Periodo  \
# 0                                           F/D  202510
# 1                                 Densitometria  202510
# 2                                 Densitometria  202510
# 3                                 Densitometria  202510
# 4                                 Densitometria  202510
# ...                                         ...     ...
# 361018                    Videoconsulta Guardia  202606
# 361019                    Videoconsulta Guardia  202606
# 361020                    Videoconsulta Guardia  202606
# 361021                    Videoconsulta Guardia  202606
# 361022                    Videoconsulta Guardia  202606
#
#        Rubro Prestacion Gerencia Estrategica  \
# 0                                        F/D
# 1                                   Imagenes
# 2                                   Imagenes
# 3                                   Imagenes
# 4                                   Imagenes
# ...                                      ...
# 361018                              Consulta
# 361019                              Consulta
# 361020                              Consulta
# 361021                              Consulta
# 361022                              Consulta
#
#        Subzona Direccion Comercial Asociado Zona Direccion Comercial Asociado  \
# 0                                     SALTA                               NOA
# 1                                   TUCUMAN                               NOA
# 2                                     SALTA                               NOA
# 3                                   MENDOZA                              CUYO
# 4                                  SAN LUIS                              CUYO
# ...                                     ...                               ...
# 361018                             CABA SUR                              AMBA
# 361019                            GBA NORTE                              AMBA
# 361020                            GBA OESTE                              AMBA
# 361021                              GBA SUR                              AMBA
# 361022                             LA PLATA                   PROVINCIA BS AS
#
#        Fecha Proceso Autorización  Cantidad Prestaciones Aceptadas
# 0                      2025-10-01                                0
# 1                      2025-10-01                                1
# 2                      2025-10-01                                3
# 3                      2025-10-01                                3
# 4                      2025-10-01                                1
# ...                           ...                              ...
# 361018                 2026-06-21                                1
# 361019                 2026-06-21                               16
# 361020                 2026-06-21                               52
# 361021                 2026-06-21                               31
# 361022                 2026-06-21                                2
#
# [361023 rows x 7 columns]

# %%
df_ambulatorio.rename(columns={'Rubro Prestacion Gerencia Estrategica':'Rubro GE',
                                                'Subrubro Prestacion Gerencia Estrategica':'Subrubro GE',
                                                'Zona Direccion Comercial Asociado':'Zona DCA',
                                                'Subzona Direccion Comercial Asociado':'Subzona DCA',
                                                'Fecha Proceso Autorización':'Fecha',
                                                'Cantidad Prestaciones Aceptadas':'Q'}, inplace=True)

# %%
df_ambulatorio
# Out:
#                   Subrubro GE Periodo  Rubro GE Subzona DCA         Zona DCA  \
# 0                         F/D  202510       F/D       SALTA              NOA
# 1               Densitometria  202510  Imagenes     TUCUMAN              NOA
# 2               Densitometria  202510  Imagenes       SALTA              NOA
# 3               Densitometria  202510  Imagenes     MENDOZA             CUYO
# 4               Densitometria  202510  Imagenes    SAN LUIS             CUYO
# ...                       ...     ...       ...         ...              ...
# 361018  Videoconsulta Guardia  202606  Consulta    CABA SUR             AMBA
# 361019  Videoconsulta Guardia  202606  Consulta   GBA NORTE             AMBA
# 361020  Videoconsulta Guardia  202606  Consulta   GBA OESTE             AMBA
# 361021  Videoconsulta Guardia  202606  Consulta     GBA SUR             AMBA
# 361022  Videoconsulta Guardia  202606  Consulta    LA PLATA  PROVINCIA BS AS
#
#             Fecha   Q
# 0      2025-10-01   0
# 1      2025-10-01   1
# 2      2025-10-01   3
# 3      2025-10-01   3
# 4      2025-10-01   1
# ...           ...  ..
# 361018 2026-06-21   1
# 361019 2026-06-21  16
# 361020 2026-06-21  52
# 361021 2026-06-21  31
# 361022 2026-06-21   2
#
# [361023 rows x 7 columns]

# %%
from src.utils.mapping import amb_rubros_subrubros

amb_rubros_subrubros(df_ambulatorio)
# Out:
# Consultando datos en el rango: amb_rubro!A1:C19...
# Consultando datos en el rango: amb_subrubro!A1:D90...
# Mapeo de rubros y subrubros aplicado correctamente.
#                   Subrubro GE Periodo  Rubro GE Subzona DCA         Zona DCA  \
# 0                         F/D  202510       F/D       SALTA              NOA
# 1               Densitometria  202510  Imagenes     TUCUMAN              NOA
# 2               Densitometria  202510  Imagenes       SALTA              NOA
# 3               Densitometria  202510  Imagenes     MENDOZA             CUYO
# 4               Densitometria  202510  Imagenes    SAN LUIS             CUYO
# ...                       ...     ...       ...         ...              ...
# 361018  Videoconsulta Guardia  202606  Consulta    CABA SUR             AMBA
# 361019  Videoconsulta Guardia  202606  Consulta   GBA NORTE             AMBA
# 361020  Videoconsulta Guardia  202606  Consulta   GBA OESTE             AMBA
# 361021  Videoconsulta Guardia  202606  Consulta     GBA SUR             AMBA
# 361022  Videoconsulta Guardia  202606  Consulta    LA PLATA  PROVINCIA BS AS
#
#             Fecha   Q          Subrubro PPTO Rubro PPTO
# 0      2025-10-01   0                  Resto      Resto
# 1      2025-10-01   1  Img. Otras Bajo Costo   Imagenes
# 2      2025-10-01   3  Img. Otras Bajo Costo   Imagenes
# 3      2025-10-01   3  Img. Otras Bajo Costo   Imagenes
# 4      2025-10-01   1  Img. Otras Bajo Costo   Imagenes
# ...           ...  ..                    ...        ...
# 361018 2026-06-21   1     Con. Videoconsulta   Consulta
# 361019 2026-06-21  16     Con. Videoconsulta   Consulta
# 361020 2026-06-21  52     Con. Videoconsulta   Consulta
# 361021 2026-06-21  31     Con. Videoconsulta   Consulta
# 361022 2026-06-21   2     Con. Videoconsulta   Consulta
#
# [361023 rows x 9 columns]

# %%
from src.utils.gc_functions import leer_tabla_df

ne_amb = leer_tabla_df('1RV39I7zo0rSBgDhmGHjaEPt0eBnLfle1L0XpvLIHI9M','NE_amb!A1:F47629')
ne_amb
# Out:
# Consultando datos en el rango: NE_amb!A1:F47629...
#          Rubro PPTO Subrubro PPTO  Zona DCA                 Subzona DCA  \
# 0         Anestesia     Anestesia      AMBA                 CABA CENTRO
# 1         Anestesia     Anestesia      AMBA                  CABA NORTE
# 2         Anestesia     Anestesia      AMBA                  CABA OESTE
# 3         Anestesia     Anestesia      AMBA                    CABA SUR
# 4         Anestesia     Anestesia      AMBA                   GBA NORTE
# ...             ...           ...       ...                         ...
# 47623  Salud Mental  Salud Mental  SANTA FE  STA FE CAP. + LAS COLONIAS
# 47624  Salud Mental  Salud Mental  SANTA FE           RAFAELA/SUNCHALES
# 47625  Salud Mental  Salud Mental  SANTA FE              SANTA FE NORTE
# 47626  Salud Mental  Salud Mental  SANTA FE                SANTA FE SUR
# 47627  Salud Mental  Salud Mental  SANTA FE  STA FE CAP. + LAS COLONIAS
#
#       Periodo    NE
# 0      202510    35
# 1      202510    18
# 2      202510    28
# 3      202510     5
# 4      202510    40
# ...       ...   ...
# 47623  202705    29
# 47624  202706  1511
# 47625  202706   236
# 47626  202706  3093
# 47627  202706    29
#
# [47628 rows x 6 columns]
