# %%
from src.stage.ambulatorio import read as stage_read

df_ambulatorio = stage_read()
df_ambulatorio

# %%
df_ambulatorio.rename(columns={'Rubro Prestacion Gerencia Estrategica':'Rubro GE',
                                                'Subrubro Prestacion Gerencia Estrategica':'Subrubro GE',
                                                'Zona Direccion Comercial Asociado':'Zona DCA',
                                                'Subzona Direccion Comercial Asociado':'Subzona DCA',
                                                'Fecha Proceso Autorización':'Fecha',
                                                'Cantidad Prestaciones Aceptadas':'Q'}, inplace=True)

# %%
df_ambulatorio

# %%
from src.utils.mapping import amb_rubros_subrubros

amb_rubros_subrubros(df_ambulatorio)

# %%
from src.utils.gc_functions import leer_tabla_df

ne_amb = leer_tabla_df('1RV39I7zo0rSBgDhmGHjaEPt0eBnLfle1L0XpvLIHI9M','NE_amb!A1:F47629')
ne_amb

# %%
from src.extract.ambulatorio import extract_feriados

extract_feriados()
# Out:
# {'feriado': DatetimeIndex(['2021-01-01', '2021-02-15', '2021-02-16', '2021-03-24',
#                 '2021-04-02', '2021-05-01', '2021-05-25', '2021-06-20',
#                 '2021-06-21', '2021-07-09',
#                 ...
#                 '2028-05-01', '2028-05-25', '2028-06-17', '2028-06-20',
#                 '2028-07-09', '2028-08-21', '2028-10-16', '2028-11-20',
#                 '2028-12-08', '2028-12-25'],
#                dtype='datetime64[ns]', name='Fecha', length=132, freq=None),
#  'no_laborable': DatetimeIndex(['2021-04-01', '2021-09-09', '2022-04-14', '2022-09-09',
#                 '2023-04-06', '2023-09-09', '2024-03-28', '2025-04-17',
#                 '2025-12-24', '2025-12-31', '2026-12-24', '2026-12-31',
#                 '2027-03-25', '2028-04-13'],
#                dtype='datetime64[ns]', name='Fecha', freq=None),
#  'turistico': DatetimeIndex(['2021-05-24', '2021-10-08', '2021-11-22', '2022-10-07',
# ...
